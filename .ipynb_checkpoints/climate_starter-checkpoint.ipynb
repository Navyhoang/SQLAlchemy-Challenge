# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt
from datetime import timedelta

# %%
from scipy import stats

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %% [markdown]
# # Explore Database

# %%
# Inspect tables names 
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
#  Inspect colunmns names of table measurement
measurement_columns = inspector.get_columns('measurement')
for c in measurement_columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Inspect colunmns names of table station
station_columns = inspector.get_columns('station')
for c in station_columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Inspect the first 5 rows of table measureme
engine.execute('SELECT * FROM measurement limit 5').fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0)]

# %%
# Inspect the first 5 rows of table station
engine.execute('SELECT * FROM station').fetchall()
# Out:
# [(1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (2, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (3, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (4, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (5, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (6, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (7, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (8, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (9, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)]

# %% [markdown]
# # Reflect Database and Create Session

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found (similar to get_tables above)
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Query and Exploratory Climate Analysis

# %% [markdown]
# Design a query to retrieve the last 12 months of precipitation data and plot the results using the DataFrame plot method.

# %%
# Get the 1st month and 12 months earlier

end_month = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
end_month = dt.date.fromisoformat(end_month[0])

start_month = end_month - timedelta(days=365)

print('Start_month:', start_month)
print('End_month:', end_month)
# Out:
# Start_month: 2016-08-23
# End_month: 2017-08-23

# %%
# Query the last 12 months of precipitation data and order in desc order by date
prcp_12mths_data = session.query(Measurement.date, Measurement.prcp)\
                        .filter(Measurement.date >= start_month)\
                        .order_by(Measurement.date.desc()).all()
prcp_12mths_data
# Out:
# [('2017-08-23', 0.0),
#  ('2017-08-23', 0.0),
#  ('2017-08-23', 0.08),
#  ('2017-08-23', 0.45),
#  ('2017-08-22', 0.0),
#  ('2017-08-22', 0.0),
#  ('2017-08-22', 0.5),
#  ('2017-08-21', 0.0),
#  ('2017-08-21', 0.02),
#  ('2017-08-21', None),
#  ('2017-08-21', 0.56),
#  ('2017-08-20', 0.0),
#  ('2017-08-20', 0.01),
#  ('2017-08-20', None),
#  ('2017-08-19', 0.0),
#  ('2017-08-19', 0.0),
#  ('2017-08-19', None),
#  ('2017-08-19', 0.09),
#  ('2017-08-18', 0.0),
#  ('2017-08-18', 0.0),
#  ('2017-08-18', 0.06),
#  ('2017-08-18', None),
#  ('2017-08-17', 0.0),
#  ('2017-08-17', 0.05),
#  ('2017-08-17', 0.01),
#  ('2017-08-17', 0.13),
#  ('2017-08-16', 0.0),
#  ('2017-08-16', 0.07),
#  ('2017-08-16', 0.12),
#  ('2017-08-16', 0.42),
#  ('2017-08-15', 0.02),
#  ('2017-08-15', 0.0),
#  ('2017-08-15', 0.06),
#  ('2017-08-15', 0.32),
#  ('2017-08-15', 0.42),
#  ('2017-08-14', 0.0),
#  ('2017-08-14', 0.01),
#  ('2017-08-14', 0.08),
#  ('2017-08-14', 0.0),
#  ('2017-08-14', 0.22),
# ...

# %%
# Unpack the tuples using list comprehension, Select only the date and prcp values.
date = [date[0] for date in prcp_12mths_data]
prcp = [prcp[1] for prcp in prcp_12mths_data ]

# Save the query results as a Pandas DataFrame and set the index to the date column
prcp_12mths_df = pd.DataFrame({
                      
                         "Date": date,
                         "Precipitation": prcp
                         
                            })
prcp_12mths_df.head()
# Out:
#          Date  Precipitation
# 0  2017-08-23           0.00
# 1  2017-08-23           0.00
# 2  2017-08-23           0.08
# 3  2017-08-23           0.45
# 4  2017-08-22           0.00

# %%
# Convert Date from object to datetime
# prcp_data_df['Date'] = pd.to_datetime(prcp_data_df['Date'], format='%Y-%m-%d')

# %%
# Set the index to the date column
prcp_12mths_df.set_index('Date', inplace=True)

# Export query to CSV
prcp_12mths_df.to_csv('prcp_12mths_data.csv')

prcp_12mths_df
# Out:
#             Precipitation
# Date
# 2017-08-23           0.00
# 2017-08-23           0.00
# 2017-08-23           0.08
# 2017-08-23           0.45
# 2017-08-22           0.00
# ...                   ...
# 2016-08-23           0.05
# 2016-08-23            NaN
# 2016-08-23           0.02
# 2016-08-23           1.79
# 2016-08-23           0.70
#
# [2230 rows x 1 columns]

# %%
# Plot the results using the DataFrame Plotting with Matplotlib
prcp_12mths_df.plot(rot=90, figsize = (10,6), grid= True)

plt.title('Precipitation Records for the Last 12 Months')
plt.xlabel('Date')
plt.ylabel('Precipitation')

plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
prcp_12mths_df.describe()
# Out:
#        Precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# # Station Analysis

# %%
# Design a query to show how many stations are available in this dataset?
station_count = session.query(Measurement).group_by(Measurement.station).count()
station_count
# Out:
# 9

# %%
# Read sql to Dataframe directly
stmt = session.query(Measurement).statement
measurement_df =  pd.read_sql_query(stmt,session.bind)
measurement_df.head()
# Out:
#    id      station        date  prcp  tobs
# 0   1  USC00519397  2010-01-01  0.08  65.0
# 1   2  USC00519397  2010-01-02  0.00  63.0
# 2   3  USC00519397  2010-01-03  0.00  74.0
# 3   4  USC00519397  2010-01-04  0.00  76.0
# 4   5  USC00519397  2010-01-06   NaN  73.0

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.

session.query(Measurement.station, func.count(Measurement.station))\
        .group_by(Measurement.station)\
        .order_by(func.count(Measurement.station).desc()).all()

#According to the results, USC00519281 is the most active station
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query
#calculate the lowest temperature recorded of the most active station

lowest_temp =  session.query(func.min(Measurement.tobs))\
       .filter(Measurement.station == 'USC00519281')\
       .all()

lowest_temp[0][0]
# Out:
# 54.0

# %%
#calculate the highest temperature recorded of the most active station
highest_temp =  session.query(func.max(Measurement.tobs))\
       .filter(Measurement.station == 'USC00519281')\
       .all()

highest_temp[0][0]
# Out:
# 85.0

# %%
#calculate the average temperature recorded of the most active station
avg_temp =  session.query(func.avg(Measurement.tobs))\
       .filter(Measurement.station == 'USC00519281')\
       .all()

round(avg_temp[0][0],1)
# Out:
# 71.7

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station
highest_obs_station_12mths_data = session.query(Measurement.tobs)\
       .order_by(Measurement.date.desc())\
       .filter(Measurement.date >= start_month).filter(Measurement.station == 'USC00519281')\
       .all() 

highest_obs_station_12mths_data
# Out:
# [(79.0),
#  (76.0),
#  (76.0),
#  (77.0),
#  (77.0),
#  (77.0),
#  (83.0),
#  (82.0),
#  (77.0),
#  (76.0),
#  (81.0),
#  (82.0),
#  (81.0),
#  (76.0),
#  (75.0),
#  (77.0),
#  (75.0),
#  (82.0),
#  (77.0),
#  (77.0),
#  (77.0),
#  (76.0),
#  (76.0),
#  (76.0),
#  (80.0),
#  (80.0),
#  (76.0),
#  (74.0),
#  (74.0),
#  (72.0),
#  (69.0),
#  (78.0),
#  (78.0),
#  (75.0),
#  (74.0),
#  (77.0),
#  (78.0),
#  (76.0),
#  (81.0),
#  (79.0),
#  (76.0),
#  (76.0),
#  (77.0),
#  (76.0),
#  (73.0),
#  (71.0),
#  (77.0),
#  (72.0),
#  (72.0),
#  (74.0),
#  (72.0),
#  (72.0),
#  (75.0),
#  (79.0),
#  (73.0),
#  (75.0),
#  (74.0),
#  (76.0),
#  (74.0),
#  (74.0),
#  (74.0),
#  (72.0),
#  (75.0),
#  (75.0),
#  (75.0),
#  (75.0),
#  (77.0),
#  (76.0),
#  (76.0),
#  (80.0),
#  (75.0),
#  (72.0),
#  (74.0),
#  (80.0),
#  (74.0),
#  (74.0),
#  (74.0),
#  (74.0),
#  (71.0),
#  (71.0),
#  (74.0),
#  (76.0),
#  (68.0),
#  (69.0),
#  (74.0),
#  (74.0),
#  (74.0),
#  (77.0),
#  (76.0),
#  (75.0),
# ...

# %%
 # Plot the results as a histogram

temp = [temp[0] for temp in highest_obs_station_12mths_data]

plt.figure(figsize=(10,6))
plt.hist(temp, align='mid', color='red', bins=12)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Station USC00519281 Temperature Histogram')
plt.show()

# %%
session.commit()
session.close()

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# Temperature Analysis I

# %%
# Identify the average temperature in June at all stations across all available years in the dataset.

# Read csv from database
conn = engine.connect()

data = pd.read_sql("SELECT * FROM measurement", conn)

june_df = data[pd.to_datetime(data['date']).dt.month == 6 ].reset_index(drop = True)
june_df
# Out:
#          id      station        date  prcp  tobs
# 0       134  USC00519397  2010-06-01  0.00  78.0
# 1       135  USC00519397  2010-06-02  0.01  76.0
# 2       136  USC00519397  2010-06-03  0.00  78.0
# 3       137  USC00519397  2010-06-04  0.00  76.0
# 4       138  USC00519397  2010-06-05  0.00  77.0
# ...     ...          ...         ...   ...   ...
# 1695  19493  USC00516128  2017-06-26  0.02  79.0
# 1696  19494  USC00516128  2017-06-27  0.10  74.0
# 1697  19495  USC00516128  2017-06-28  0.02  74.0
# 1698  19496  USC00516128  2017-06-29  0.04  76.0
# 1699  19497  USC00516128  2017-06-30  0.20  75.0
#
# [1700 rows x 5 columns]

# %%
# Average Jun temp across all stations

jun_avg = round(june_df['tobs'].mean(),1)
print(f" June average temp: {jun_avg}")
# Out:
#  June average temp: 74.9

# %%
# Do the same for December temperature
dec_df = data[pd.to_datetime(data['date']).dt.month == 12 ].reset_index(drop = True)
dec_df
# Out:
#          id      station        date  prcp  tobs
# 0       306  USC00519397  2010-12-01  0.04  76.0
# 1       307  USC00519397  2010-12-03  0.00  74.0
# 2       308  USC00519397  2010-12-04  0.00  74.0
# 3       309  USC00519397  2010-12-06  0.00  64.0
# 4       310  USC00519397  2010-12-07  0.00  64.0
# ...     ...          ...         ...   ...   ...
# 1512  19324  USC00516128  2016-12-27  0.14  71.0
# 1513  19325  USC00516128  2016-12-28  0.14  71.0
# 1514  19326  USC00516128  2016-12-29  1.03  69.0
# 1515  19327  USC00516128  2016-12-30  2.37  65.0
# 1516  19328  USC00516128  2016-12-31  0.90  65.0
#
# [1517 rows x 5 columns]

# %%
# Average Dec temp across all stations

dec_avg = round(dec_df['tobs'].mean(),1)
print(f" December average temp: {dec_avg}")
# Out:
#  December average temp: 71.0

# %%
# Use t-test to compare 2 mean values
# Paired t-test is used when the same group is tested twice (before and after)
# Unpaired t-test is used to compare the mean of 2 independent groups (men vs women group taking same drug)

# This case, since the temperature in Jun and Dec are 2 different sets/groups, we use unpaired t-test
# scipy.stats.ttest_ind

jun_array = june_df['tobs']
dec_array = dec_df['tobs']

stats.ttest_ind(jun_array, dec_array)
# Out:
# Ttest_indResult(statistic=31.60372399000329, pvalue=3.9025129038616655e-191)

# %%
# Reading t_test: source https://www.dummies.com/education/math/statistics/what-a-p-value-tells-you-about-statistical-data/
# Large p_value (>0.05 or 0.1): fail to reject null hypothesis, 2 mean values are identical
# Small p_value (<0.05): reject null hypothesis, 2 mean value are not identical

# In this case, p value is 3.9 >>> 0.1
# Thus Jun and Dec average temoperature are not significantly different from each other

# %% [markdown]
# Temperature Analysis II

# %%
start_date = input(str(f"Start date in the format %Y-%m-%d:"))
end_date = input(str(f"End date in the format %Y-%m-%d:"))
# Out:
# Start date in the format %Y-%m-%d:2016-06-01
# End date in the format %Y-%m-%d:2016-06-30

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    
    result = session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs))\
                     .filter(Measurement.date >= start_date)\
                     .filter(Measurement.date <= end_date).all()
    print(f"Min temp:")
    print(result[0][0])
    print("------------")
    print(f"Avr temp:")
    print(round(result[0][1],1))
    print("------------")
    print(f"Max temp:")
    print(result[0][2])

calc_temps(start_date, end_date)
# Out:
# Min temp:
# 64.0
# ------------
# Avr temp:
# 75.2
# ------------
# Max temp:
# 81.0

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

calc_temps('2017-06-01','2017-06-30')
# Out:
# Min temp:
# 71.0
# ------------
# Avr temp:
# 77.2
# ------------
# Max temp:
# 83.0

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

result = session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs))\
                     .filter(Measurement.date >= start_date)\
                     .filter(Measurement.date <= end_date).all()


avg_temp = result[0][1]
avg_temp_df = (pd.DataFrame({"Avg Temp": avg_temp}, index=[0]))

# %%
tmax = avg_temp = result[0][0]
tmin = avg_temp = result[0][2]

# %%
x_tick = 1
y = avg_temp_df["Avg Temp"]
y_error_bar = tmax - tmin

# Plot with subplot
fig, ax = plt.subplots(figsize = plt.figaspect(2.))
ax.set(xticks=range(x_tick), title = "Trip Avg Temp", ylabel="Temp(F)")
ax.bar(x_tick, y, yerr = y_error_bar, color = 'coral', align='center')
ax.margins(0.3,0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Daily Rainfall Average

# %%
# Calculate the rainfall per weather station using the previous year's matching dates
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

trip_start = '2017-06-01'
trip_end = '2017-06-30'

rainfall = session.query(Measurement.station, Station.name, func.sum(Measurement.prcp), Station.latitude, Station.longitude, Station.elevation)\
        .outerjoin(Station, Measurement.station == Station.station)\
        .filter(Measurement.date >= trip_start)\
        .filter(Measurement.date <= trip_end)\
        .group_by(Measurement.station)\
        .order_by(func.sum(Measurement.prcp).desc())\
        .all()

rainfall
# Out:
# [('USC00516128',
#   'MANOA LYON ARBO 785.2, HI US',
#   9.299999999999997,
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   'WAIHEE 837.5, HI US',
#   4.26,
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   'KANEOHE 838.1, HI US',
#   2.9799999999999995,
#   21.4234,
#   -157.8015,
#   14.6),
#  ('USC00514830',
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   2.6,
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523',
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   0.8900000000000001,
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   'WAIKIKI 717.2, HI US',
#   0.37000000000000005,
#   21.2716,
#   -157.8168,
#   3.0),
#  ('USC00517948', 'PEARL CITY, HI US', 0.12, 21.3934, -157.9751, 11.9)]

# %%
# Unpack the tuple
station = [station[0] for station in rainfall]
name = [name[1] for name in rainfall]
prcp_sum = [prcp_sum[2] for prcp_sum in rainfall]
lat = [lat[3] for lat in rainfall]
lon = [lon[0] for lon in rainfall]
elv = [elv[0] for elv in rainfall]

# Put into a dafaframe
rainfall_df = pd.DataFrame({
                      
                         "Station": station,
                         "Name": name,
                         "Total Precipitation": prcp_sum,
                         "Latitude": lat,
                         "Longitude": lon,
                         "Elevation": elv,
                         
                            })
rainfall_df
# Out:
#        Station                                    Name  Total Precipitation  \
# 0  USC00516128            MANOA LYON ARBO 785.2, HI US                 9.30
# 1  USC00519281                     WAIHEE 837.5, HI US                 4.26
# 2  USC00513117                    KANEOHE 838.1, HI US                 2.98
# 3  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US                 2.60
# 4  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US                 0.89
# 5  USC00519397                    WAIKIKI 717.2, HI US                 0.37
# 6  USC00517948                       PEARL CITY, HI US                 0.12
#
#    Latitude    Longitude    Elevation
# 0  21.33310  USC00516128  USC00516128
# 1  21.45167  USC00519281  USC00519281
# 2  21.42340  USC00513117  USC00513117
# 3  21.52130  USC00514830  USC00514830
# 4  21.33556  USC00519523  USC00519523
# 5  21.27160  USC00519397  USC00519397
# 6  21.39340  USC00517948  USC00517948

# %%
# Calculate the daily normals. Normals are the averages for the min, avg, and max temperatures
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.strftime("%m-%d", Measurement.date), func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [('01-01', 62.0, 69.15384615384616, 77.0)]

# %%
# Create a list of dates for your trip in the format %m-%d. 
# Set the start and end date of the trip
# Use the start and end date to create a range of dates

trip_start = '2017-06-01'
trip_end = '2017-06-30'

query = session.query(func.strftime("%m-%d", Measurement.date)).filter(Measurement.date >= trip_start).filter(Measurement.date <= trip_end).all()

date_list = [date[0] for date in query]
date_list
# Out:
# ['06-01',
#  '06-02',
#  '06-03',
#  '06-04',
#  '06-05',
#  '06-06',
#  '06-07',
#  '06-08',
#  '06-09',
#  '06-10',
#  '06-11',
#  '06-12',
#  '06-13',
#  '06-14',
#  '06-15',
#  '06-16',
#  '06-17',
#  '06-18',
#  '06-19',
#  '06-20',
#  '06-21',
#  '06-22',
#  '06-23',
#  '06-24',
#  '06-25',
#  '06-26',
#  '06-27',
#  '06-28',
#  '06-29',
#  '06-30',
#  '06-01',
#  '06-02',
#  '06-03',
#  '06-04',
#  '06-05',
#  '06-06',
#  '06-07',
#  '06-08',
#  '06-09',
#  '06-10',
#  '06-11',
#  '06-12',
#  '06-13',
#  '06-14',
#  '06-15',
#  '06-16',
#  '06-17',
#  '06-18',
#  '06-19',
#  '06-20',
#  '06-21',
#  '06-22',
#  '06-23',
#  '06-24',
#  '06-25',
#  '06-26',
#  '06-27',
#  '06-28',
#  '06-29',
#  '06-30',
#  '06-01',
#  '06-02',
#  '06-03',
#  '06-04',
#  '06-05',
#  '06-06',
#  '06-07',
#  '06-08',
#  '06-09',
#  '06-10',
#  '06-11',
#  '06-12',
#  '06-13',
#  '06-14',
#  '06-15',
#  '06-16',
#  '06-17',
#  '06-18',
#  '06-19',
#  '06-20',
#  '06-23',
#  '06-26',
#  '06-29',
# ...

# %%
# Use the daily_normals function to calculate the normals for each date string and append the results to a list.

normals_list = []

for date in date_list:
    normals_list.append(daily_normals(date)[0])
    
normals_list
# Out:
# [('06-01', 64.0, 74.6140350877193, 81.0),
#  ('06-02', 65.0, 74.4, 81.0),
#  ('06-03', 65.0, 74.03448275862068, 80.0),
#  ('06-04', 65.0, 73.81818181818181, 81.0),
#  ('06-05', 68.0, 74.85454545454546, 81.0),
#  ('06-06', 70.0, 75.17543859649123, 80.0),
#  ('06-07', 68.0, 75.07142857142857, 81.0),
#  ('06-08', 70.0, 75.58620689655173, 81.0),
#  ('06-09', 69.0, 75.15254237288136, 81.0),
#  ('06-10', 68.0, 75.14285714285714, 81.0),
#  ('06-11', 69.0, 76.01960784313725, 84.0),
#  ('06-12', 66.0, 75.66666666666667, 83.0),
#  ('06-13', 68.0, 75.66666666666667, 81.0),
#  ('06-14', 69.0, 75.62711864406779, 81.0),
#  ('06-15', 67.0, 75.40350877192982, 81.0),
#  ('06-16', 69.0, 75.41379310344827, 81.0),
#  ('06-17', 68.0, 74.59322033898304, 81.0),
#  ('06-18', 69.0, 74.60344827586206, 80.0),
#  ('06-19', 70.0, 75.44067796610169, 82.0),
#  ('06-20', 68.0, 73.96491228070175, 85.0),
#  ('06-21', 68.0, 74.75862068965517, 82.0),
#  ('06-22', 69.0, 75.15789473684211, 81.0),
# ...

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
column_names = ['Date', 'Min_Prcp', 'Avg_Prcp', 'Max_Prcp']
df = pd.DataFrame(normals_list, columns=column_names).set_index('Date')
df.head(31)
# Out:
#        Min_Prcp   Avg_Prcp  Max_Prcp
# Date
# 06-01      64.0  74.614035      81.0
# 06-02      65.0  74.400000      81.0
# 06-03      65.0  74.034483      80.0
# 06-04      65.0  73.818182      81.0
# 06-05      68.0  74.854545      81.0
# 06-06      70.0  75.175439      80.0
# 06-07      68.0  75.071429      81.0
# 06-08      70.0  75.586207      81.0
# 06-09      69.0  75.152542      81.0
# 06-10      68.0  75.142857      81.0
# 06-11      69.0  76.019608      84.0
# 06-12      66.0  75.666667      83.0
# 06-13      68.0  75.666667      81.0
# 06-14      69.0  75.627119      81.0
# 06-15      67.0  75.403509      81.0
# 06-16      69.0  75.413793      81.0
# 06-17      68.0  74.593220      81.0
# 06-18      69.0  74.603448      80.0
# 06-19      70.0  75.440678      82.0
# 06-20      68.0  73.964912      85.0
# 06-21      68.0  74.758621      82.0
# 06-22      69.0  75.157895      81.0
# 06-23      68.0  74.543860      80.0
# 06-24      68.0  74.964286      84.0
# ...

# %%
# Plot the daily normals as an area plot with `stacked=False`
df.plot(kind='area', figsize=(15,10), title="Daily Rainfall Normals", stacked=False)
plt.xlabel("Date")
plt.ylabel("Temperature (F)")
# Out:
# Text(0, 0.5, 'Temperature (F)')

# %%
session.commit()
session.close()
